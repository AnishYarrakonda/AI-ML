# %%
import pandas as pd

# %%
cars = pd.read_csv("carsdata.csv")

# %%
cars
# Out:
#    Unnamed: 0       brand     model  year  price
# 0         idx       brand     model  year  price
# 1           0       Tesla   Model 3  2018  14000
# 2           1        Ford   Mustang  2007   5000
# 3           2      Toyota     Camry  2022  20500
# 4           3         BMW        M5  2019  50000
# 5           4       Honda     Civic  2020  12300
# 6           5   Chevrolet    Malibu  2016   9800
# 7           6      Nissan    Altima  2015   8700
# 8           7        Audi        A4  2018  26500
# 9           8     Hyundai   Elantra  2021  16200
# 10          9         Kia    Optima  2019  14500
# 11         10    Mercedes      C300  2017  28900
# 12         11      Subaru   Outback  2020  22300
# 13         12  Volkswagen     Jetta  2016   9100
# 14         13        Ford     F-150  2018  32000
# 15         14      Toyota   Corolla  2014   7200
# 16         15       Honda    Accord  2021  24500
# 17         16       Tesla   Model Y  2022  48000
# ...
